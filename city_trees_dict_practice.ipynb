# %%
import csv 


tree_summary = {"tree_type": {},}

with open("city-pgh-trees.csv") as tree_file: 
    dreader = csv.DictReader(tree_file)
#     print(dreader.fieldnames)


    for record in dreader:
        if record["common_name"] not in tree_summary["tree_type"]:
            tree_summary["tree_type"][record["common_name"]] = 1
        else:
            tree_summary["tree_type"][record["common_name"]] +=1            
            
            

    for y in sorted(tree_summary["tree_type"]):
        # prints the year, the end count from above
        print(y, ":", tree_summary["tree_type"][y], end=" ")
        print("\n")
        

#                     if record["ZIP_CODE"] not in tri_summary["location"]:
#             tri_summary["location"][record["ZIP_CODE"]] = 1
#         else:
#             tri_summary["location"][record["ZIP_CODE"]] += 1
# Out:
#  : 103
#
# Amur Corktree : 45
#
# Amur Maackia : 19
#
# Apple: Common : 23
#
# Apple: Paradise : 1
#
# Arborvitae: Eastern : 324
#
# Ash: Black : 2
#
# Ash: Green : 247
#
# Ash: White : 229
#
# Ash: spp. : 108
#
# Baldcypress: Common : 130
#
# Barberry: Japanese : 1
#
# Beech: American : 12
#
# Beech: European : 39
#
# Birch: European White : 5
#
# Birch: Gray : 11
#
# Birch: Paper : 31
#
# Birch: River : 68
#
# Birch: Yellow : 5
#
# Boxelder : 47
#
# Boxwood: spp. : 1
#
# Buckeye spp. : 4
#
# Buckeye: Ohio : 95
#
# Buckeye: Red : 20
#
# Buckeye: Yellow : 19
#
# Buckthorn: Common : 3
#
# Butternut : 6
#
# Catalpa: Northern : 70
#
# Cedar: Atlas : 4
#
# Cherry/Plum: spp. : 579
#
# Cherry: Black : 178
#
# Cherry: Higan : 10
#
# Cherry: Japanese Flowering : 105
#
# Cherry: Pin : 10
#
# Cherry: Sargent : 2
#
# Cherry: Sweet : 22
#
# Cherry: Yoshino : 9
#
# Chestnut: American : 5
#
# Chestnut: Chinese : 9
#
# Chokecherry: Common : 27
#
# Coffeetree: Kentucky : 111
#
# Cottonwood: Eastern : 10
#
# Crabapple: Donald Wyman Flowering : 1
#
# Crabapple: Flowering : 1310
#
# Cryptomeria: Japanese : 1
#
# Dawn Redwood : 48
#
# Dogwood: Corneliancherry : 206
#
# Dogwood: Flowering : 136
#
# Dogwood: Kousa : 106
#
# Dogwood: Pagoda : 1
#
# Dogwood: Roughleaf : 4
#
# Dogwood: spp. : 1
#
# Douglas-fir : 14
#
# Elderberry: Common : 1
#
# Elm: American : 798
#
# Elm: Hybrid : 91
#
# Elm: Lacebark : 42
#
# Elm: Siberian : 210
#
# Elm: Slippery : 12
#
# Elm: Winged : 1
#
# Elm: spp. : 416
#
# Evodia: Korean : 1
#
# Falsecypress: Lawson : 1
#
# Falsecypress: Nootka : 5
#
# Falsecypress: Sawara : 7
#
# Fig: Common : 2
#
# Filbert: American : 1
#
# Filbert: Beaked : 1
#
# Filbert: Turkish : 46
#
# Fir: Balsam : 7
#
# Fir: Fraser : 1
#
# Fir: White : 3
#
# Fringetree: Chinese : 1
#
# Fringetree: White : 3
#
# Ginkgo : 1218
#
# Goldenchain Tree : 2
#
# Goldenraintree : 76
#
# Hackberry: Common : 142
#
# Hardy Rubbertree : 48
#
# Hawthorn: Green : 3
#
# Hawthorn: spp. : 398
#
# Hemlock: Eastern : 98
#
# Hickory: Bitternut : 7
#
# Hickory: Mockernut : 2
#
# Hickory: Pignut : 3
#
# Holly: American : 44
#
# Honeylocust : 101
#
# Honeylocust: Thornless : 2019
#
# Hophornbeam: American : 80
#
# Hornbeam: American : 141
#
# Hornbeam: European : 235
#
# Horsechestnut : 235
#
# Horsechestnut: Red : 5
#
# Juniper: spp. : 1
#
# Katsuratree : 36
#
# Larch: American : 2
#
# Larch: Golden : 1
#
# Lilac: Common : 3
#
# Lilac: Japanese Tree : 600
#
# Linden: American : 126
#
# Linden: Littleleaf : 2413
#
# Linden: Silver : 128
#
# Linden: Silver Pendant : 11
#
# Locust: Black : 689
#
# London planetree : 3238
#
# Magnolia: Bigleaf : 1
#
# Magnolia: Cucumbertree : 24
#
# Magnolia: Saucer : 55
#
# Magnolia: Southern : 3
#
# Magnolia: Star : 4
#
# Magnolia: Sweetbay : 43
#
# Magnolia: Umbrella : 6
#
# Magnolia: spp. : 26
#
# Maple: Amur : 118
#
# Maple: Black : 20
#
# Maple: Freeman : 789
#
# Maple: Hedge : 573
#
# Maple: Japanese : 154
#
# Maple: Miyabei : 138
#
# Maple: Norway : 3717
#
# Maple: Paperbark : 48
#
# Maple: Red : 3422
#
# Maple: Shantung : 1
#
# Maple: Silver : 432
#
# Maple: Striped : 1
#
# Maple: Sugar : 716
#
# Maple: Sycamore : 38
#
# Maple: Tatarian : 89
#
# Maple: Trident : 9
#
# Maple: Truncatum x : 4
#
# Maple: spp. : 17
#
# Mimosa : 10
#
# Mountainash: American : 2
#
# Mountainash: European : 2
#
# Mulberry: Paper : 1
#
# Mulberry: Red : 15
#
# Mulberry: White : 385
#
# Non-sufficient space : 2
#
# Oak, Hybrid : 19
#
# Oak: Black : 24
#
# Oak: Bur : 68
#
# Oak: Chestnut : 13
#
# Oak: Chinkapin : 18
#
# Oak: English : 24
#
# Oak: Northern Red : 978
#
# Oak: Pin : 1672
#
# Oak: Sawtooth : 57
#
# Oak: Scarlet : 68
#
# Oak: Shingle : 37
#
# Oak: Swamp White : 232
#
# Oak: Turkey : 6
#
# Oak: Water : 4
#
# Oak: White : 97
#
# Oak: Willow : 3
#
# Oak: spp. : 27
#
# Osage-orange : 40
#
# Pagodatree: Japanese : 43
#
# Pawpaw: Common : 4
#
# Peach: Common : 8
#
# Pear: Callery : 2969
#
# Pear: Common : 21
#
# Pear: spp. : 48
#
# Pecan : 1
#
# Persian Parrotia : 42
#
# Persimmon: Common : 2
#
# Pine: Austrian : 192
#
# Pine: Eastern White : 230
#
# Pine: Lacebark : 10
#
# Pine: Limber : 1
#
# Pine: Mugo : 5
#
# Pine: Ponderosa : 2
#
# Pine: Red : 2
#
# Pine: Scotch : 124
#
# Pine: Virginia : 1
#
# Pine: White Japanese : 1
#
# Pine: spp. : 3
#
# Plum: American : 1
#
# Plum: Canada : 2
#
# Plum: Cherry : 30
#
# Poplar: Carolina : 1
#
# Poplar: Lombardy : 4
#
# Poplar: White : 1
#
# Redbud: Eastern : 253
#
# Redbud: Southwestern : 8
#
# Redcedar: Eastern : 86
#
# Rose-of-Sharon : 14
#
# Russian-olive : 3
#
# Sassafras : 8
#
# Sequoia : 2
#
# Serviceberry: Downy : 214
#
# Serviceberry: Eastern : 34
#
# Serviceberry: Smooth : 98
#
# Serviceberry: Western : 1
#
# Serviceberry: spp. : 76
#
# Silverbell: Carolina : 2
#
# Silverbell: Mountain : 2
#
# Smoketree: American : 3
#
# Smoketree: Common : 11
#
# Snowbell: American : 1
#
# Snowbell: Japanese : 2
#
# Spruce: Alberta White : 3
#
# Spruce: Colorado : 472
#
# Spruce: Engelmann : 1
#
# Spruce: Norway : 249
#
# Spruce: Serbian : 2
#
# Spruce: White : 59
#
# Spruce: spp. : 7
#
# Stump : 1079
#
# Sumac: Smooth : 2
#
# Sumac: Staghorn : 1
#
# Sweetgum: American : 892
#
# Sycamore: American : 233
#
# Tree-of-Heaven : 217
#
# Tuliptree : 186
#
# Tupelo: Black : 43
#
# Unknown : 173
#
# Unknown Shrub : 2
#
# Vacant Site Large : 562
#
# Vacant Site Medium : 365
#
# Vacant Site Not Suitable : 846
#
# Vacant Site Small : 2419
#
# Viburnum: Blackhaw : 7
#
# Walnut: Black : 49
#
# Walnut: English : 4
#
# Whitecedar: Atlantic : 3
#
# Willow: Black : 5
#
# Willow: Hankow : 7
#
# Willow: Pussy : 4
#
# Willow: Weeping : 4
#
# Willow: spp. : 1
#
# Wisteria: spp. : 2
#
# Witchhazel: Common : 7
#
# Yellowwood: American : 18
#
# Yew: spp. : 25
#
# Zelkova: Japanese : 610
