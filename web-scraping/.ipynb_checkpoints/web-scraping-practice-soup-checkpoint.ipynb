# %%
# class practice using goodreads 

import urllib 
from bs4 import BeautifulSoup  

def get_search_url_goodreads(search_term):
    url = 'https://www.goodreads.com/search?query=%s' % (str(search_term))
    return url 

def get_search_url_devto(search_term):
    url = 'https://dev.to/search?q=%s' % (str(search_term))
    return url

def get_page_content(url):
    req = urllib.request.Request(url)
    with urllib.request.urlopen(req) as response:
        return response.read()

# %%
user_input = input("What book content would you like to look up: ")
print()

page_content = get_page_content(get_search_url_goodreads(user_input.lower()))

#print(page_content)
soup = BeautifulSoup(page_content, 'html.parser')
# print(soup)
# bookTitle is the class

s = soup.find_all('a','bookTitle')
# print(s)

total_titles = 0
subtitles = 0

for item in s:
    # finds everything in the span element to just get the titles 
    t = item.find('span').string
    print(t)
    total_titles = total_titles + 1
    # if there is a title with : in it it has a subtitle
    if ":" in t:
        subtitles = subtitles + 1
        
print()
print("********SUMMARY**********")
print()
print("Total Titles on the first page: ", str(total_titles))
print(str((subtitles/total_titles)*100),"% of titles have subtitles")
# Out:
# What book content would you like to look up: moon
#
# New Moon (Twilight, #2)
# Goodnight Moon
# Moon Called (Mercy Thompson, #1)
# Killers of the Flower Moon: The Osage Murders and the Birth of the FBI
# Gardens of the Moon (Malazan Book of the Fallen, #1)
# Fool Moon (The Dresden Files, #2)
# The Moon Is a Harsh Mistress
# Walk Two Moons
# The Girl Who Drank the Moon
# New Moon: The Complete Illustrated Movie Companion (The Twilight Saga: The Official Illustrated Movie Companion, #2)
# Blue Moon (The Immortals, #2)
# Keeping the Moon
# The Last of the Moon Girls
# Empire of the Summer Moon: Quanah Parker and the Rise and Fall of the Comanches, the Most Powerful Indian Tribe in American History
# The Girl Who Chased the Moon
# Blue Moon (Anita Blake, Vampire Hunter, #8)
# The Moon and More
# Sailor Moon, Vol. 1 (Sailor Moon, #1)
# Emily of New Moon (Emily, #1)
# Bone Crier's Moon (Bone Grace, #1)
#
# ********SUMMARY**********
#
# Total Titles on the first page:  20
# ...

# %%
user_input = input("What topic would you like to look up on dev.to:  ")
print()

page_content = get_page_content(get_search_url_devto(user_input.lower()))

soup = BeautifulSoup(page_content, 'html.parser')

soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US">
# <head>
# <link href="https://cf.geekdo-static.com/icons/touch-icon180.png" rel="apple-touch-icon"/>
# <link href="https://cf.geekdo-static.com/icons/favicon2.ico" rel="shortcut icon" type="image/ico"/>
# <link href="https://cf.geekdo-static.com/icons/favicon2.ico" rel="icon" type="image/ico"/>
# <link href="/game-opensearch.xml" rel="search" title="BGG Game Search" type="application/opensearchdescription+xml"/>
# <meta content="BGG" name="apple-mobile-web-app-title"/>
# <link href="https://www.google.com" rel="preconnect"/>
# <link href="https://api.geekdo.com" rel="preconnect"/>
# <meta content="board game, boardgames, boardgame, board, games, game, hobby, boardgamegeek, geek, geekdo" name="keywords"/>
# <title>BoardGameGeek</title>
# <meta charset="utf-8">
# <!-- Load the Proxima Nova font -->
# <link href="https://use.typekit.net/ddz3tbb.css" rel="stylesheet"/>
# <style type="text/css">
#       body {
#         margin: 0;
# ...
