# %%
# documentation https://projects.propublica.org/nonprofits/api

# import requests, json 

# hardcoding the propublica nonprofit url 
# API_ENDPOINT = "https://projects.propublica.org/nonprofits/api/v2"

#all data
#response = requests.get("https://projects.propublica.org/nonprofits/api/v2/search.json?")

#just the organization propublica
# response = requests.get("https://projects.propublica.org/nonprofits/api/v2/search.json?q=propublica")

# all organizations with the id of ( 7 - Public, Societal Benefit in this case) 
# response = requests.get("https://projects.propublica.org/nonprofits/api/v2/search.json?ntee%5Bid%5D=7")

#all organizations within PA
#response = requests.get("https://projects.propublica.org/nonprofits/api/v2/search.json?state%5Bid%5D=PA")

# all organization with a specific taxcode
# response = requests.get("https://projects.propublica.org/nonprofits/api/v2/search.json?c_code%5Bid%5D=3")


# print(response.status_code)
# print(response.text)
# Out:
# {"total_results":65437,"organizations":[{"ein":364912784,"strein":"36-4912784","name":"1 PERCENT FOR NATURE INC","sub_name":"1 PERCENT FOR NATURE INC","city":"STROUDSBURG","state":"PA","ntee_code":"C30","raw_ntee_code":"C30","subseccd":3,"has_subseccd":true,"have_filings":null,"have_extracts":null,"have_pdfs":null,"score":3.0412173},{"ein":813173199,"strein":"81-3173199","name":"1 THESSALONIANS 3-2 INC","sub_name":"1 THESSALONIANS 3-2 INC","city":"LANGHORNE","state":"PA","ntee_code":"X20","raw_ntee_code":"X20","subseccd":3,"has_subseccd":true,"have_filings":null,"have_extracts":null,"have_pdfs":null,"score":3.0412173},{"ein":455094951,"strein":"45-5094951","name":"109TH INFANTRY REGIMENT ASSOCIATION","sub_name":"109TH INFANTRY REGIMENT ASSOCIATION","city":"SCRANTON","state":"PA","ntee_code":"P99","raw_ntee_code":"P99","subseccd":3,"has_subseccd":true,"have_filings":null,"have_extracts":null,"have_pdfs":null,"score":3.0412173},{"ein":464233500,"strein":"46-4233500","name":"11TH STREET FAMILY HEALTH SERVICES INC","sub_name":"11TH STREET FAMILY HEALTH SERVICES INC","city":"PHILADELPHIA","state":"PA","ntee_code":"E32","raw_ntee_code":"E32","subseccd":3,"has_subseccd":true,"have_filings":null,"have_extracts":null,"have_pdfs":null,"score":3.0412173},{"ein":452090710,"strein":"45-2090710","name":"12 PEERS THEATER COMPANY","sub_name":"12 PEERS THEATER COMPANY","city":"PITTSBURGH","state":"PA","ntee_code":"A65","raw_ntee_code":"A65","subseccd":3,"has_subseccd":true,"have_filings":null,"have_extracts":null,"have_pdfs":null,"score":3.0412173},{"ein":460540608,"strein":"46-0540608","name":"12TH HOUSE ENTERTAINMENT","sub_name":"12TH HOUSE ENTERTAINMENT","city":"DREXEL HILL","state":"PA","ntee_code":"O50","raw_ntee_code":"O50","subseccd":3,"has_subseccd":true,"have_filings":null,"have_extracts":null,"have_pdfs":null,"score":3.0412173},{"ein":272613375,"strein":"27-2613375","name":"1492 SOCIETY","sub_name":"1492 SOCIETY","city":"PHILADELPHIA","state":"PA","ntee_code":"A23","raw_ntee_code":"A23","subseccd":3,"has_subseccd":true,"have_filings":null,"have_extracts":null,"have_pdfs":null,"score":3.0412173},{"ein":232801799,"strein":"23-2801799","name":"1889-CHS FOUNDATION INC","sub_name":"1889-CHS FOUNDATION INC","city":"JOHNSTOWN","state":"PA","ntee_code":"X00Z","raw_ntee_code":"X00Z","subseccd":3,"has_subseccd":true,"have_filings":null,"have_extracts":null,"have_pdfs":null,"score":3.0412173},{"ein":526076146,"strein":"52-6076146","name":"1922 CLASS OF THE UNITED STATES NAVAL ACADEMY MEMORIAL SCHOLARSHIP","sub_name":"1922 CLASS OF THE UNITED STATES NAVAL ACADEMY MEMORIAL SCHOLARSHIP","city":"PITTSBURGH","state":"PA","ntee_code":null,"raw_ntee_code":null,"subseccd":3,"has_subseccd":true,"have_filings":null,"have_extracts":null,"have_pdfs":null,"score":3.0412173},{"ein":452410261,"strein":"45-2410261","name":"1926 FOUNDATION","sub_name":"1926 FOUNDATION","city":"PHILADELPHIA","state":"PA","ntee_code":"B60","raw_ntee_code":"B60","subseccd":3,"has_subseccd":true,"have_filings":null,"have_extracts":null,"have_pdfs":null,"score":3.0412173},{"ein":208567861,"strein":"20-8567861","name":"1981 LODGE","sub_name":"1981 LODGE","city":"YORK","state":"PA","ntee_code":"N50","raw_ntee_code":"N50","subseccd":7,"has_subseccd":true,"have_filings":null,"have_extracts":null,"have_pdfs":null,"score":3.0412173},{"ein":471202182,"strein":"47-1202182","name":"1ST CHOICE CASE MANAGEMENT","sub_name":"1ST CHOICE CASE MANAGEMENT","city":"JOHNSTOWN","state":"PA","ntee_code":"P80","raw_ntee_code":"P80","subseccd":3,"has_subseccd":true,"have_filings":null,"have_extracts":null,"have_pdfs":null,"score":3.0412173},{"ein":813375288,"strein":"81-3375288","name":"2 FISH HOME RENOVATIONS","sub_name":"2 FISH HOME RENOVATIONS","city":"AVONDALE","state":"PA","ntee_code":"J22","raw_ntee_code":"J22","subseccd":3,"has_subseccd":true,"have_filings":null,"have_extracts":null,"have_pdfs":null,"score":3.0412173},{"ein":232265134,"strein":"23-2265134","name":"21ST WARD JUNIOR BASEBALL LEAGUE", ...

# %%
def build_url(state):
    ''' a function that builds a URL given a users state preference'''
    API_ENDPOINT = "https://projects.propublica.org/nonprofits/api/v2/search.json?"
    full_url = API_ENDPOINT + "state%5Bid%5D=" + state 
    print("Endpoint URL: ", full_url)
    return full_url 

def make_api_request(url):
    ''' a function that turns that request data into usable data'''
    response = requests.get(url)
    print('Made request, response status: ', response.status_code)
    if(int(response.status_code) == 200):
        payload_obj = json.loads(response.text)
        return payload_obj
    else:
        return None

def print_state_info(request_data, state):
    ''' a function that takes in the dataset and users state and prints out how many nonprofits are in that state'''
    print("There are", request_data["total_results"], "nonprofits in", state)
    print()
    
    
def main():
    users_state = input("What state would you like to see nonprofit information about? -ex input, PA -   ")
    request_data = make_api_request(build_url(users_state))
    print_state_info(request_data, users_state)
   
main()
# Out:
# What state would you like to see nonprofit information about? -ex input, PA -   PA
# Endpoint URL:  https://projects.propublica.org/nonprofits/api/v2/search.json?state%5Bid%5D=PA
# Made request, response status:  200
# There are 65437 nonprofits in PA
